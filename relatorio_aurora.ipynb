# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandrerussi/Aurora-Siger/blob/main/relatorio_aurora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Título do relatório

# %%
print("Hello")
# Out:
# Hello

# %%
eficiencia_energica = 123
print(eficiencia_energica)
# Out:
# 123

# %%
print("novo ajuste")
# Out:
# novo ajuste
